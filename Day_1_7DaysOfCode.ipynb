# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizGustavo8/Day1-7DaysOfCode/blob/main/Day_1_7DaysOfCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dia 1 - Explorar dados de empréstimos dos acervos do sistema de bibliotecas da UFRN.

# %% [markdown]
# Desafio: Dados baixados? Ok, mas são diversas tabelas diferentes e isso dificulta o trabalho. Portanto, o seu primeiro passo é **unificar** em um único Dataframe todos os dados pertinentes para a análise.
#
# Comece pelos **empréstimos** e você terá os dados das transações. Depois, **mescle** com os dados do **acervo**, para que você possa entender, por exemplo, de qual biblioteca era o material emprestado ou a qual tema ele se referia. Elas se relacionam pela coluna de **código de barras** de cada material.
#
# Lembre-se que é muito comum receber **dados nulos** ou **duplicados**, por isso não deixe de fazer a **limpeza**.

# %% [markdown]
# Importando bibliotecas:

# %%
import pandas as pd

# %%
import glob

# %% [markdown]
# Importando os dados diretamente do Github para o notebook:

# %%
# !git clone https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas.git
# Out:
# Cloning into '7_Days_of_Code_Alura-Python-Pandas'...
# remote: Enumerating objects: 282, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 282 (delta 29), reused 0 (delta 0), pack-reused 220
# Receiving objects: 100% (282/282), 82.88 MiB | 16.69 MiB/s, done.
# Resolving deltas: 100% (102/102), done.
# Updating files: 100% (33/33), done.

# %% [markdown]
# Esquema para ler os múltiplos arquivos csv, definindo o data frame para os empréstimos:

# %%
path = f'/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/'

# %%
all_files = glob.glob(path + "*.csv")

# %%
all_files
# Out:
# ['/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv',
#  '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv']

# %%
li = []

# %%
for filename in all_files:
        df = pd.read_csv(filename)
        li.append(df)

df_emprestimos = pd.concat(li, axis=0, ignore_index=True)

# %%
df_emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0        2962509    2007005628                            NaN
# 1        2962510       L202802                            NaN
# 2        2962511    2012008328                            NaN
# 3        2962512    2012055016  2020/01/17 09:56:18.380000000
# 4        2962513       L197391  2020/01/17 23:50:18.862000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2020/01/02 08:17:30.290000000  2020/01/07 11:14:07.000000000
# 1  2020/01/02 08:17:30.391000000  2020/01/07 11:14:17.000000000
# 2  2020/01/02 08:17:30.436000000  2020/01/07 11:24:46.000000000
# 3  2020/01/02 08:36:40.163000000  2020/01/31 14:53:52.000000000
# 4  2020/01/02 09:36:03.877000000  2020/01/24 08:18:19.000000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# 1        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# 2        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# 3        2.019015e+10      ALUNO DE GRADUAÇÃO
# 4        2.018005e+10      ALUNO DE GRADUAÇÃO

# %% [markdown]
# Importando os dados dos exemplares, arquivo parquet:

# %%
parquet_path = '/content/7_Days_of_Code_Alura-Python-Pandas/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet'

parquet_data = pd.read_parquet(parquet_path)

df_exemplares = parquet_data

# %%
df_exemplares.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %% [markdown]
# ## Análisando os dados

# %% [markdown]
# ### Empréstimos

# %%
df_emprestimos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2258018 entries, 0 to 2258017
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 120.6+ MB

# %%
df_emprestimos.describe(include = object)
# Out:
#        codigo_barras                 data_renovacao  \
# count        2258018                         972298
# unique        276757                         970947
# top       2010091988  2010/11/03 00:00:00.000000000
# freq             196                             30
#
#                       data_emprestimo                 data_devolucao  \
# count                         2258018                        2251547
# unique                        2257902                        2229749
# top     2010/01/04 09:58:46.522000000  2012/07/02 12:35:12.024000000
# freq                                7                             12
#
#        tipo_vinculo_usuario
# count               2258018
# unique                    8
# top      ALUNO DE GRADUAÇÃO
# freq                1769197

# %% [markdown]
# Convertendo ID e Matrícula em string e os campos de data para datetime:

# %%
df_emprestimos['matricula_ou_siape'] = df_emprestimos['matricula_ou_siape'].astype(str).str.rstrip('.0')
df_emprestimos['id_emprestimo'] = df_emprestimos['id_emprestimo'].astype(str)
df_emprestimos[['data_emprestimo', 'data_renovacao', 'data_devolucao']] = df_emprestimos[['data_emprestimo', 'data_renovacao', 'data_devolucao']].apply(pd.to_datetime)

# %%
df_emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao           data_emprestimo          data_devolucao           matricula_ou_siape  tipo_vinculo_usuario
# 709705         2009032168     2010-01-17 18:56:43.909  2010-01-04 09:58:46.549  2010-01-20 13:14:34.464  200800989           ALUNO DE GRADUAÇÃO        7
# 709704         2006021442     2010-01-17 18:56:43.923  2010-01-04 09:58:46.522  2010-02-01 13:59:02.528  200800989           ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010-01-18 14:44:41.163  2010-01-04 09:21:19.099  2010-02-02 12:02:38.444  2009046838          ALUNO DE GRADUAÇÃO        3
# 2461099        2012008348     2016-06-27 20:35:46.855  2016-06-14 11:20:33.254  2016-07-11 14:37:29.000  2015021539          ALUNO DE GRADUAÇÃO        2
# 2351386        2015005192     2016-01-16 07:41:19.537  2016-01-02 10:02:44.507  2016-01-30 07:52:07.000  2015315556          ALUNO MÉDIO/TÉCNICO       2
#                                                                                                                                                       ..
# 1652214        C024311        2014-01-02 09:22:46.685  2013-12-04 17:03:44.748  2014-02-03 19:03:05.000  2011216916          ALUNO DE PÓS-GRADUAÇÃO    1
# 1652215        2011076295     2014-01-02 09:22:46.594  2013-12-04 17:03:44.807  2014-02-03 19:02:58.000  2011216916          ALUNO DE PÓS-GRADUAÇÃO    1
# 1652227        L192312        2014-01-02 17:24:36.605  2013-12-04 17:17:52.362  2014-01-07 14:46:54.000  2011100071          ALUNO DE PÓS-GRADUAÇÃO    1
# 1652228        2010039883     2014-01-02 17:24:36.375  2013-12-04 17:17:52.408  2014-01-07 14:47:01.000  2011100071          ALUNO DE PÓS-GRADUAÇÃO    1
# 9999996        2010091715     2017-08-28 00:33:45.446  2017-08-16 16:20:12.379  2017-09-11 20:51:02.000  2016010736          ALUNO DE GRADUAÇÃO        1
# Length: 968755, dtype: int64

# %% [markdown]
# Há alguns valores duplicados, vamos remove-los:

# %%
df_emprestimos = df_emprestimos.drop_duplicates()

# %%
df_emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao           data_emprestimo          data_devolucao       matricula_ou_siape  tipo_vinculo_usuario
# 10000000       2015036976     2017-08-29 20:19:14.111  2017-08-16 16:21:35.442  2017-09-27 15:04:18  2012937973          ALUNO DE GRADUAÇÃO        1
# 2651525        2014077389     2018-05-17 18:54:15.716  2018-05-02 13:43:52.357  2018-05-29 14:16:35  2014078143          ALUNO DE GRADUAÇÃO        1
# 2651494        2010033801     2018-05-16 09:59:44.446  2018-05-02 13:17:16.834  2018-05-24 13:43:42  2014070548          ALUNO DE GRADUAÇÃO        1
# 2651495        2011001533     2018-05-16 09:59:44.414  2018-05-02 13:17:16.886  2018-05-24 13:43:45  2014070548          ALUNO DE GRADUAÇÃO        1
# 2651496        2014007624     2018-05-16 06:05:41.939  2018-05-02 13:17:21.503  2018-06-01 12:48:32  2015075781          ALUNO DE GRADUAÇÃO        1
#                                                                                                                                                   ..
# 1652214        C024311        2014-01-02 09:22:46.685  2013-12-04 17:03:44.748  2014-02-03 19:03:05  2011216916          ALUNO DE PÓS-GRADUAÇÃO    1
# 1652215        2011076295     2014-01-02 09:22:46.594  2013-12-04 17:03:44.807  2014-02-03 19:02:58  2011216916          ALUNO DE PÓS-GRADUAÇÃO    1
# 1652227        L192312        2014-01-02 17:24:36.605  2013-12-04 17:17:52.362  2014-01-07 14:46:54  2011100071          ALUNO DE PÓS-GRADUAÇÃO    1
# 1652228        2010039883     2014-01-02 17:24:36.375  2013-12-04 17:17:52.408  2014-01-07 14:47:01  2011100071          ALUNO DE PÓS-GRADUAÇÃO    1
# 9999996        2010091715     2017-08-28 00:33:45.446  2017-08-16 16:20:12.379  2017-09-11 20:51:02  2016010736          ALUNO DE GRADUAÇÃO        1
# Length: 968755, dtype: int64

# %%
df_emprestimos.isnull().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1285709
# data_emprestimo               0
# data_devolucao             6471
# matricula_ou_siape            0
# tipo_vinculo_usuario          0
# dtype: int64

# %% [markdown]
# Podemos verificar a existência de valores nulos, mas por serem referentes a data de renovação e devolução, os campos em questão podem fazer referência a livros que foram devolvidos sem renovação ou que nunca foram devolvidos, portanto é pertinente manter esses dados.

# %% [markdown]
# ### Exemplares

# %%
df_exemplares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 546237 entries, 0 to 568584
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_exemplar       546237 non-null  int64
#  1   codigo_barras     546237 non-null  object
#  2   colecao           546237 non-null  object
#  3   biblioteca        546237 non-null  object
#  4   status_material   546237 non-null  object
#  5   localizacao       546237 non-null  int64
#  6   registro_sistema  546237 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 33.3+ MB

# %% [markdown]
# Convertendo ID e Registro em string:

# %%
df_exemplares[['id_exemplar', 'registro_sistema']] = df_exemplares[['id_exemplar', 'registro_sistema']].astype(str)

# %%
df_exemplares.head()
# Out:
#       id_exemplar codigo_barras            colecao  \
# index
# 0               5       L000003  Acervo Circulante
# 1               4       L000002  Acervo Circulante
# 2               3       L000001  Acervo Circulante
# 3               7       L000114  Acervo Circulante
# 5              10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#       registro_sistema
# index
# 0                    1
# 1                    1
# 2                    1
# 3                    5
# 5                   15

# %%
df_exemplares.value_counts()
# Out:
# id_exemplar  codigo_barras  colecao            biblioteca                                                                                status_material  localizacao  registro_sistema
# 10           L000041        Acervo Circulante  Biblioteca Central Zila Mamede                                                            ESPECIAL         657          15                  1
# 254150       2008039472     Acervo Circulante  Biblioteca Central Zila Mamede                                                            REGULAR          645          108478              1
# 254163       2008045487     Dissertações       Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ            ESPECIAL         682          14666               1
# 254162       2008045103     Acervo Circulante  Biblioteca Central Zila Mamede                                                            REGULAR          660          108488              1
# 254161       2008021587     Acervo Circulante  Biblioteca Central Zila Mamede                                                            REGULAR          611          108487              1
#                                                                                                                                                                                           ..
# 1259505      2017017295     Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba  REGULAR          602          13923               1
# 1259504      2017017301     Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba  REGULAR          530          232302              1
# 1259503      2017017299     Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba  REGULAR          529          232312              1
# 1259502      2017017300     Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba  REGULAR          604          49787               1
# 999999       2012039686     Acervo Circulante  Biblioteca Central Zila Mamede                                                            REGULAR          385          183491              1
# Length: 546237, dtype: int64

# %%
df_exemplares.isnull().sum()
# Out:
# id_exemplar         0
# codigo_barras       0
# colecao             0
# biblioteca          0
# status_material     0
# localizacao         0
# registro_sistema    0
# dtype: int64

# %% [markdown]
# Não há duplicados e não há valores nulos.

# %% [markdown]
# Unindo os DataFrames:

# %%
df_biblioteca = df_emprestimos.merge(df_exemplares)

# %%
df_biblioteca.head()
# Out:
#   id_emprestimo codigo_barras          data_renovacao         data_emprestimo  \
# 0       2962509    2007005628                     NaT 2020-01-02 08:17:30.290
# 1       2786530    2007005628 2019-02-25 08:47:56.972 2019-01-24 15:34:01.986
# 2       2833897    2007005628 2019-05-05 20:25:01.740 2019-04-04 16:38:33.910
# 3       9457816    2007005628 2017-03-02 00:18:47.926 2017-02-14 18:15:01.198
# 4       9730128    2007005628 2017-06-05 17:26:35.090 2017-05-05 17:11:54.811
#
#        data_devolucao matricula_ou_siape    tipo_vinculo_usuario id_exemplar  \
# 0 2020-01-07 11:14:07        20181028903  ALUNO DE PÓS-GRADUAÇÃO      216276
# 1 2019-03-21 15:14:17        20181004349  ALUNO DE PÓS-GRADUAÇÃO      216276
# 2 2019-05-28 13:30:39        20181004788  ALUNO DE PÓS-GRADUAÇÃO      216276
# 3 2017-03-16 13:02:01         2012957958      ALUNO DE GRADUAÇÃO      216276
# 4 2017-07-05 17:51:44        20161009526  ALUNO DE PÓS-GRADUAÇÃO      216276
#
#              colecao                      biblioteca status_material  \
# 0  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 1  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 2  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 3  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 4  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
#
#    localizacao registro_sistema
# 0          640            87626
# 1          640            87626
# 2          640            87626
# 3          640            87626
# 4          640            87626
